# %%
# !git clone https://github.com/ArtemisFwl/PPE-detection-YOLO.git
# Out:
# Cloning into 'PPE-detection-YOLO'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 0), reused 10 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), done.

# %%
cd PPE-detection-YOLO
# Out:
# /content/PPE-detection-YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="gEhjDBvDmELW1MmZA3ox")
project = rf.workspace("amanppedetection").project("helmet-evxi3-achsr")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 85.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 135.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to helmet-1 in yolov8:: 100%|██████████| 1654/1654 [00:00<00:00, 8623.34it/s]

# %%
cat helmet-1/data.yaml
# Out:
# names:
# - helmet
# nc: 1
# roboflow:
#   license: CC BY 4.0
#   project: helmet-evxi3-achsr
#   url: https://universe.roboflow.com/amanppedetection/helmet-evxi3-achsr/dataset/1
#   version: 1
#   workspace: amanppedetection
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model=YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(data="helmet-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
print("Best model saved at:")
print("runs/detect/train/weights/best.pt")
# Out:
# Best model saved at:
# runs/detect/train/weights/best.pt
